# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
print(f"Open CV version {cv2.__version__}")
print(f"Numpy version {np.__version__}")


img = np.zeros((100, 100, 3), dtype=np.uint8)
img[:] = [255, 0, 0] # BRG - Blue, Red, Green


plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Day 1 - Blue square")
plt.axis('off')
plt.show()
# Out:
# Open CV version 4.13.0
# Numpy version 2.4.6

# %%
img = cv2.imread("data/Presentation.jpg")
img.shape
# Out:
# (4032, 3024, 3)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("My pic using CV")
plt.axis('off')
plt.show()

# %%
print(f"Image shape: {img.shape}")
print(f"Image DType: {img.dtype}")
print(f"Min pixel: {img.min()}")
print(f"Max pixel: {img.max()}")
# Out:
# Image shape: (4032, 3024, 3)
# Image DType: uint8
# Min pixel: 0
# Max pixel: 255

# %%
print(f"Top left pixel - BRG: {img[0,0]}")
print(f"Centeral Pixel - BRG: {img[img.shape[0]//2, img.shape[1]//2]}")
print(f"Bottom right pixel - BRG: {img[4031, 3023]}")
# Out:
# Top left pixel - BRG: [175 184 193]
# Centeral Pixel - BRG: [97 66 57]
# Bottom right pixel - BRG: [204 191 175]

# %%
grey_img = cv2.imwrite("data/gray_image.jpg", cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
hsv = cv2.imwrite("data/hsv_image.jpg", cv2.cvtColor(img, cv2.COLOR_BGR2HSV))
